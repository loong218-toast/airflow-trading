# %%
import ipywidgets as widgets
from tqdm.auto import tqdm
import time

# Test 1: Simple Widget
display(widgets.IntSlider(value=50, description='If you see this, widgets are FIXED:'))

# Test 2: Clear and Run TQDM
tqdm._instances.clear()
for i in tqdm(range(10), desc="Testing Progress Bar"):
    time.sleep(0.1)
# Out:
# IntSlider(value=50, description='If you see this, widgets are FIXED:')
# Testing Progress Bar:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
pip install --upgrade ipywidgets jupyterlab-widgets
