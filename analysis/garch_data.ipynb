# %%
import polars as pl

# Define the file path
file_path = r"C:\Users\Owner\airflow-trading\data_lake\garch_qlike_scan\session_20260411T174510Z\garch_qlike_detail_all.parquet"

# Load the dataframe
df = pl.read_parquet(file_path)

# 1. Show the first 5 rows (head)
print("--- Table Head ---")
print(df.head())

# 2. Show total rows and columns (shape)
print(f"\nTotal Rows: {df.height}")
print(f"Total Columns: {df.width}")

# 3. Show the schema (column names and data types)
print("\n--- Table Schema ---")
print(df.schema)

# BONUS: Use glimpse() for a summary of everything (shape, schema, and first few values)
print("\n--- Data Glimpse ---")
df.glimpse()
# Out:
# --- Table Head ---
# shape: (5, 24)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ job_id    ┆ timeframe ┆ time_ns   ┆ train_win ┆ … ┆ last_sigm ┆ last_resi ┆ sample_va ┆ cached_f │
# │ ---       ┆ _min      ┆ ---       ┆ dow_days  ┆   ┆ a2        ┆ d2        ┆ r_train   ┆ it_origi │
# │ str       ┆ ---       ┆ i64       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ n        │
# │           ┆ i64       ┆           ┆ i64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ tf15m_101 ┆ 15        ┆ 175358250 ┆ 60        ┆ … ┆ 0.006669  ┆ 0.001771  ┆ 0.030703  ┆ 101760   │
# │ 760_10660 ┆           ┆ 000000000 ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
